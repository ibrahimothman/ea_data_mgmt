# %%
# Building the DDL for all the silver tables based on the schema defined in the config

# %%
dbutils.library.restartPython()

# %%
from ea_pipeline.config import DATASET_CONTRACTS, spark
from ea_pipeline.silver_ddl import silver_ddl

for dataset_name in DATASET_CONTRACTS:
    ddl = silver_ddl(dataset_name)
    print(ddl)
    spark.sql(ddl)
    print("→ created\n")

# %%
# %sql
describe table ea_dev.silver.applications
